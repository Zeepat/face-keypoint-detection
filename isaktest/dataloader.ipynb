# %%
import torch

print(f"{torch.__version__=}")
print(f"{torch.cuda.is_available()=}")
# Out:
# torch.__version__='2.5.1+cu121'
# torch.cuda.is_available()=True

# %%
import os
import matplotlib.pyplot as plt
import random

img_dir_path = "../data/AFLW/aflw-images-2/2/"

random_img = random.choice(os.listdir(img_dir_path))

img = os.path.join(img_dir_path, random_img)

plt.imshow(plt.imread(img))

# %%
from ultralytics import YOLO

model = YOLO("yolo11n-pose.pt")

# %%
results = model(img)

# plt.imshow(results[0])
results
# Out:
# image 1/1 c:\KODA\ITHS\9_Deep Learning\GruppProjekt\face-keypoint-detection\isak\..\data\AFLW\aflw-images-2\2\image66685.jpg: 448x640 1 person, 32.5ms
# Speed: 2.5ms preprocess, 32.5ms inference, 5.5ms postprocess per image at shape (1, 3, 448, 640)
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: ultralytics.engine.results.Keypoints object
#  masks: None
#  names: {0: 'person'}
#  obb: None
#  orig_img: array([[[ 81, 169, 186],
#          [ 79, 169, 186],
#          [ 80, 170, 187],
#          ...,
#          [ 54,  57,  61],
#          [ 56,  59,  63],
#          [ 56,  59,  63]],
#
#         [[ 78, 166, 183],
#          [ 76, 166, 183],
#          [ 74, 166, 183],
#          ...,
#          [ 56,  59,  63],
#          [ 58,  61,  65],
#          [ 58,  61,  65]],
#
#         [[ 74, 164, 181],
#          [ 72, 164, 181],
#          [ 72, 164, 181],
#          ...,
#          [ 61,  64,  68],
#          [ 57,  60,  64],
#          [ 57,  60,  64]],
#
#         ...,
#
#         [[ 60,  66,  61],
#          [ 63,  69,  64],
#          [ 64,  70,  65],
#          ...,
#          [ 23,  44,  71],
#          [ 27,  46,  79],
#          [ 26,  45,  82]],
#
#         [[ 59,  65,  60],
#          [ 64,  70,  65],
#          [ 66,  72,  67],
#          ...,
#          [ 22,  43,  70],
#          [ 26,  45,  78],
#          [ 25,  44,  81]],
#
#         [[ 59,  65,  60],
#          [ 65,  71,  66],
#          [ 68,  74,  69],
#          ...,
#          [ 30,  51,  78],
#          [ 29,  48,  81],
#          [ 28,  47,  84]]], shape=(518, 778, 3), dtype=uint8)
#  orig_shape: (518, 778)
#  path: 'c:\\KODA\\ITHS\\9_Deep Learning\\GruppProjekt\\face-keypoint-detection\\isak\\..\\data\\AFLW\\aflw-images-2\\2\\image66685.jpg'
#  probs: None
#  save_dir: 'c:\\KODA\\ITHS\\9_Deep Learning\\GruppProjekt\\face-keypoint-detection\\runs\\pose\\predict'
#  speed: {'preprocess': 2.499818801879883, 'inference': 32.52053260803223, 'postprocess': 5.501270294189453}]
